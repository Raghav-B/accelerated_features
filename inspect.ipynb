# %%
import onnx

# %%
# Load the ONNX model
model = onnx.load("onnx_weights/extractor.onnx")
# Check if the model is well-formed
onnx.checker.check_model(model)

# %%
# Print the graph definition
# print(onnx.helper.printable_graph(model.graph))

for input in model.graph.input:
    print(f"Input: {input.name}, Type: {input.type}")

for output in model.graph.output:
    print(f"Output: {output.name}, Type: {output.type}")
# Out:
# Input: keypoints0, Type: tensor_type {
#   elem_type: 1
#   shape {
#     dim {
#       dim_value: 1
#     }
#     dim {
#       dim_value: 100
#     }
#     dim {
#       dim_value: 2
#     }
#   }
# }
#
# Input: keypoints1, Type: tensor_type {
#   elem_type: 1
#   shape {
#     dim {
#       dim_value: 1
#     }
#     dim {
#       dim_value: 100
#     }
#     dim {
#       dim_value: 2
#     }
#   }
# }
#
# Input: descriptors0, Type: tensor_type {
#   elem_type: 1
#   shape {
#     dim {
#       dim_value: 1
#     }
#     dim {
#       dim_value: 100
#     }
#     dim {
#       dim_value: 64
#     }
#   }
# }
#
# Input: descriptors1, Type: tensor_type {
#   elem_type: 1
#   shape {
#     dim {
#       dim_value: 1
#     }
#     dim {
#       dim_value: 100
#     }
#     dim {
#       dim_value: 64
#     }
#   }
# }
#
# Input: image_size0, Type: tensor_type {
#   elem_type: 6
#   shape {
#     dim {
#       dim_value: 1
#     }
#     dim {
#       dim_value: 2
#     }
#   }
# }
#
# Input: image_size1, Type: tensor_type {
#   elem_type: 6
#   shape {
#     dim {
#       dim_value: 1
#     }
#     dim {
#       dim_value: 2
#     }
#   }
# }
#
# Output: log_assignment, Type: tensor_type {
#   elem_type: 1
#   shape {
#     dim {
#       dim_value: 1
#     }
#     dim {
#       dim_value: 101
#     }
#     dim {
#       dim_value: 101
#     }
#   }
# }
#
# Output: matches0, Type: tensor_type {
#   elem_type: 7
#   shape {
#     dim {
#       dim_value: 1
#     }
#     dim {
#       dim_value: 100
#     }
#   }
# }
#
# Output: matches1, Type: tensor_type {
#   elem_type: 7
#   shape {
#     dim {
#       dim_value: 1
#     }
#     dim {
#       dim_value: 100
#     }
#   }
# }
#
# Output: matching_scores0, Type: tensor_type {
#   elem_type: 1
#   shape {
#     dim {
#       dim_value: 1
#     }
#     dim {
#       dim_value: 100
#     }
#   }
# }
#
# Output: matching_scores1, Type: tensor_type {
#   elem_type: 1
#   shape {
#     dim {
#       dim_value: 1
#     }
#     dim {
#       dim_value: 100
#     }
#   }
# }
